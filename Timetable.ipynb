# %% [markdown]
# ## Timetable Excel File - Preprocessing

# %% [markdown]
# #### Including Required Libraries

# %%
import pandas as pd
import numpy as np

# %%
file_path = "FAST School of Computing - Fall 2022 - V0.xlsx"
my_section = "BSE-5A"
exclude_combine_section_course = "BAI";
sheet_ = "BS(SE) BATCH 2020"

# %% [markdown]
# ### Reading Courses and Faculty name for my FALL-22 Semester

# %%
df = pd.read_excel(file_path , sheet_name= sheet_, header=4,
                   skiprows=lambda  x: x in [5], skipfooter=1, index_col=2)
#Skipping invalid rows

# %%
df.head(5)
# Out:
#         Unnamed: 0 S. No.                             Course Title    Short  \
# Code
# CS2005         NaN    1.0                         Database Systems       DB
# CL2005         NaN    2.0                     Database Systems Lab   DB-Lab
# SE3001         NaN    3.0      Software Construction & Development      SCD
# SL3001         NaN    4.0  Software Construction & Development Lab  SCD-Lab
# SE3002         NaN    5.0             Software Quality Engineering      SQE
#
#         Sections  Crd.Hr.   Batch  \
# Code
# CS2005       2.0      3.0  2020.0
# CL2005       2.0      1.0  2020.0
# SE3001       2.0      3.0  2020.0
# SL3001       2.0      1.0  2020.0
# SE3002       2.0      3.0  2020.0
#
#                                    Instructors (Sections)
# Code
# CS2005  Dr. Zulfiqar Ali Memon  (BSE-5B)\nMs. Anam Qur...
# CL2005  Ms. Erum Shaheen (BSE-5B)\nMs. Syeda Ulya Seer...
# SE3001  Mr. Abdul Rahman (BSE-5A)\nMs. Abeeha Sattar (...
# SL3001                   Ms. Nida Munawar (BSE-5A,BSE-5B)
# SE3002  Ms. Romasha Khurshid (BSE-5A)\nMs. Syeda Rubab...

# %% [markdown]
# #### Removing the Redundant column

# %%
df = df.drop(columns='Unnamed: 0')  
df
# Out:
#                  S. No.                             Course Title    Short  \
# Code
# CS2005              1.0                         Database Systems       DB
# CL2005              2.0                     Database Systems Lab   DB-Lab
# SE3001              3.0      Software Construction & Development      SCD
# SL3001              4.0  Software Construction & Development Lab  SCD-Lab
# SE3002              5.0             Software Quality Engineering      SQE
# SS 2007             6.0             Technical & Business Writing      TBW
# CS2009              7.0          Design & Analysis of Algorithms     Algo
# NaN      REPEAT COURSES                                      NaN      NaN
# CS2006              8.0                        Operating Systems       OS
# CL2006              9.0                    Operating Systems Lab   OS-Lab
# MT2005              NaN                Probability & Statistics     Prob
#
#          Sections  Crd.Hr.   Batch  \
# Code
# CS2005        2.0      3.0  2020.0
# CL2005        2.0      1.0  2020.0
# SE3001        2.0      3.0  2020.0
# SL3001        2.0      1.0  2020.0
# SE3002        2.0      3.0  2020.0
# SS 2007       2.0      3.0  2020.0
# CS2009        2.0      3.0  2020.0
# NaN           NaN      NaN     NaN
# CS2006        1.0      3.0  2020.0
# CL2006        1.0      1.0  2020.0
# MT2005        1.0      3.0  2020.0
#
#                                     Instructors (Sections)
# Code
# CS2005   Dr. Zulfiqar Ali Memon  (BSE-5B)\nMs. Anam Qur...
# CL2005   Ms. Erum Shaheen (BSE-5B)\nMs. Syeda Ulya Seer...
# SE3001   Mr. Abdul Rahman (BSE-5A)\nMs. Abeeha Sattar (...
# SL3001                    Ms. Nida Munawar (BSE-5A,BSE-5B)
# SE3002   Ms. Romasha Khurshid (BSE-5A)\nMs. Syeda Rubab...
# SS 2007  Ms. Sabeen Amjad (BSE-5A)\nMs. Madiha Rehman (...
# CS2009                    Dr. Waheed Ahmed (BSE-5A,BSE-5B)
# NaN                                                    NaN
# CS2006   Course Planning: BSE-5A(BSE ,BAI, & BCY)  \nDr...
# CL2006   Course Planning: BSE-5A(BSE ,BAI, & BCY) \nMr....
# MT2005   Course Planning: BCS-5A(BCS & BSE)\nMr. Muhamm...

# %% [markdown]
# #### Removing  Rows having most values NULL

# %%
def detectNullRow(x):
    # print(pd.isna(x.name))
    if(~pd.isna(x.name)):      #x.name should be a valid obj/str
        return(df.loc[x.name].isnull().sum() >= 3)   #if null value count exceed 3, then that row needs to be removed
    
mask = df.apply(lambda x: detectNullRow(x) , axis=1)
indexes = df.loc[mask].index

df = df.drop(index = indexes)

# %%
df
# Out:
#         S. No.                             Course Title    Short  Sections  \
# Code
# CS2005     1.0                         Database Systems       DB       2.0
# CL2005     2.0                     Database Systems Lab   DB-Lab       2.0
# SE3001     3.0      Software Construction & Development      SCD       2.0
# SL3001     4.0  Software Construction & Development Lab  SCD-Lab       2.0
# SE3002     5.0             Software Quality Engineering      SQE       2.0
# SS 2007    6.0             Technical & Business Writing      TBW       2.0
# CS2009     7.0          Design & Analysis of Algorithms     Algo       2.0
# CS2006     8.0                        Operating Systems       OS       1.0
# CL2006     9.0                    Operating Systems Lab   OS-Lab       1.0
# MT2005     NaN                Probability & Statistics     Prob        1.0
#
#          Crd.Hr.   Batch                             Instructors (Sections)
# Code
# CS2005       3.0  2020.0  Dr. Zulfiqar Ali Memon  (BSE-5B)\nMs. Anam Qur...
# CL2005       1.0  2020.0  Ms. Erum Shaheen (BSE-5B)\nMs. Syeda Ulya Seer...
# SE3001       3.0  2020.0  Mr. Abdul Rahman (BSE-5A)\nMs. Abeeha Sattar (...
# SL3001       1.0  2020.0                   Ms. Nida Munawar (BSE-5A,BSE-5B)
# SE3002       3.0  2020.0  Ms. Romasha Khurshid (BSE-5A)\nMs. Syeda Rubab...
# SS 2007      3.0  2020.0  Ms. Sabeen Amjad (BSE-5A)\nMs. Madiha Rehman (...
# CS2009       3.0  2020.0                   Dr. Waheed Ahmed (BSE-5A,BSE-5B)
# CS2006       3.0  2020.0  Course Planning: BSE-5A(BSE ,BAI, & BCY)  \nDr...
# CL2006       1.0  2020.0  Course Planning: BSE-5A(BSE ,BAI, & BCY) \nMr....
# MT2005       3.0  2020.0  Course Planning: BCS-5A(BCS & BSE)\nMr. Muhamm...

# %% [markdown]
# #### Replacing "\n" with commas (optional)

# %%
df["Instructors (Sections)"] = df["Instructors (Sections)"]. apply(lambda x: x.replace("\n", " , "))

# %%
df.head()
# Out:
#        S. No.                             Course Title    Short  Sections  \
# Code
# CS2005    1.0                         Database Systems       DB       2.0
# CL2005    2.0                     Database Systems Lab   DB-Lab       2.0
# SE3001    3.0      Software Construction & Development      SCD       2.0
# SL3001    4.0  Software Construction & Development Lab  SCD-Lab       2.0
# SE3002    5.0             Software Quality Engineering      SQE       2.0
#
#         Crd.Hr.   Batch                             Instructors (Sections)
# Code
# CS2005      3.0  2020.0  Dr. Zulfiqar Ali Memon  (BSE-5B) , Ms. Anam Qu...
# CL2005      1.0  2020.0  Ms. Erum Shaheen (BSE-5B) , Ms. Syeda Ulya See...
# SE3001      3.0  2020.0  Mr. Abdul Rahman (BSE-5A) , Ms. Abeeha Sattar ...
# SL3001      1.0  2020.0                   Ms. Nida Munawar (BSE-5A,BSE-5B)
# SE3002      3.0  2020.0  Ms. Romasha Khurshid (BSE-5A) , Ms. Syeda Ruba...

# %% [markdown]
# Required DataFrame is obtained, now you can export it into excel file

# %%
#df.to_excel("Instrutor details.xlsx")

# %% [markdown]
# ### Now Reading the Daywise Timetable of my section

# %% [markdown]
# First, we try to get Timetable for Monday only, afterwards, we loop it over for other Days

# %%
df = pd.read_excel(file_path, sheet_name="MONDAY", header=2)

# %%
df.head(3)
# Out:
#   Venues/time                      08-8:50                      08:55-09:45  \
# 0  CLASSROOMS                          NaN                              NaN
# 1          E1  PF-BCS-1J\nMr. Musawar Ali             CAG-BCS-1J\nMs. Urooj
# 2          E2  CAG-BCS-1A\nMr. Nadeem Khan  PF-BCS-1A\nDr. Farooque Hassan
#
#              09:50-10:40              10:45-11:35  \
# 0                    NaN                      NaN
# 1  CAG-BCS-1J\nMs. Urooj                      NaN
# 2   AP-BCS-1A\nMr. Waqar  CN-BCS-7A(A-J)\nAbuzar
#
#                         11:40-12:30                      12:35-01:25  \
# 0                               NaN                              NaN
# 1        PF-BCS-1C\nMr. Musawar Ali            CAG-BCS-1C\nMs. Urooj
# 2  PDC-BCS-5A\nDr. Nausheen Shoaib   ECC-BCS-1A\nMs. Khadija Shireen
#
#                        01:30-02:20                      02:25-03:15  \
# 0                              NaN                              NaN
# 1       GT-BCS-5A\nMr. Abdul Basit  TOA-BCS-5A(A-F)\nMr. M. Shahzad
# 2  ECC-BCS-1A\nMs. Khadija Shireen                              NaN
#
#   03:20-04:10
# 0         NaN
# 1         NaN
# 2         NaN

# %%
# Transposing the data-frame so that index would be the time of the classes(better in terms of understanding the data)
df = df.T   
df.head(3)
# Out:
#                      0                            1   \
# Venues/time  CLASSROOMS                           E1
# 08-8:50             NaN  PF-BCS-1J\nMr. Musawar Ali
# 08:55-09:45         NaN        CAG-BCS-1J\nMs. Urooj
#
#                                           2                            3   \
# Venues/time                               E2                           E3
# 08-8:50          CAG-BCS-1A\nMr. Nadeem Khan  PF-BCS-1F\nMr. M. Shahzad
# 08:55-09:45  PF-BCS-1A\nDr. Farooque Hassan   PF-BCS-1F\nMr. M. Shahzad
#
#                                     4                              5   \
# Venues/time                         E4                             E5
# 08-8:50      PF-BSE-1A\nMs. Aqsa Zahid  AP-BSE-1B\nMs. Rabia Tabassum
# 08:55-09:45  PF-BSE-1A\nMs. Aqsa Zahid  AP-BSE-1B\nMs. Rabia Tabassum
#
#                                       6                                  7   \
# Venues/time                           E6                                R12
# 08-8:50      CAG-BCY-1B\nMs. Asma Masood  AI-BCS-7A(BCS & BAI)\nMir Murtaza
# 08:55-09:45  CAG-BCY-1B\nMs. Asma Masood    DS-BCS-3E\nDr. Jawwad A. Shamsi
#
#                                        8                              9   ...  \
# Venues/time                          R109                        LLC(R7)  ...
# 08-8:50      PF-BCY-3A\n Ms. Atiya Jokhio  DS-BCS-3B\nDr. Fahad Sherwani  ...
# 08:55-09:45       CN-BCS-7A(A-J)\nAbuzar      COAL-BCS-3A\nMr. Aamir Ali  ...
#
#                                           31  \
# Venues/time                            Lab-4
# 08-8:50      DS LAB-BCS-3G\nMs. Mafaza Mohi
# 08:55-09:45                              NaN
#
#                                                     32  \
# Venues/time                                      Lab-5
# 08-8:50      OOP LAB-BCS-3G(G,H,J,K,L)\nMs. Ayesha Ali
# 08:55-09:45                                        NaN
#
#                                            33  \
# Venues/time                            Lab-11
# 08-8:50      DS LAB-BCS-3H\nMr. Zuhair Waheed
# 08:55-09:45                               NaN
#
#                                            34  \
# Venues/time                            Lab-12
# 08-8:50      DS LAB-BCS-3J\nMr. M. Ali Fatimi
# 08:55-09:45                               NaN
#
#                                            35  \
# Venues/time                          EE Lab-6
# 08-8:50      DS LAB-BCS-3K\nMr. Mustafa Mirza
# 08:55-09:45                               NaN
#
#                                                 36        37  \
# Venues/time                               EE Lab-7  EE Lab-8
# 08-8:50      ICT LAB-BS(RA)-1C\nMr. Arsalan Sattar       NaN
# 08:55-09:45                                    NaN       NaN
#
#                                         38          39               40
# Venues/time                      EE Lab-10  EE MPI Lab  Electronics Lab
# 08-8:50      DB LAB-BCS-5D\nMr. Amin Sadiq         NaN              NaN
# 08:55-09:45                            NaN         NaN              NaN
#
# [3 rows x 41 columns]

# %%
#Removing the column indexes (after transposing) as they are of no meaning.    #Don't run it more than once  
#Making classroom names as column indexes now
df.columns = df.iloc[0]
df = df.drop(df.index[0]) 
df.head(3)
# Out:
# Venues/time CLASSROOMS                           E1  \
# 08-8:50            NaN  PF-BCS-1J\nMr. Musawar Ali
# 08:55-09:45        NaN        CAG-BCS-1J\nMs. Urooj
# 09:50-10:40        NaN        CAG-BCS-1J\nMs. Urooj
#
# Venues/time                               E2                              E3  \
# 08-8:50          CAG-BCS-1A\nMr. Nadeem Khan     PF-BCS-1F\nMr. M. Shahzad
# 08:55-09:45  PF-BCS-1A\nDr. Farooque Hassan      PF-BCS-1F\nMr. M. Shahzad
# 09:50-10:40             AP-BCS-1A\nMr. Waqar  COAL-BCY-3A\n Ms. Atiya Jokhio
#
# Venues/time                         E4                             E5  \
# 08-8:50      PF-BSE-1A\nMs. Aqsa Zahid  AP-BSE-1B\nMs. Rabia Tabassum
# 08:55-09:45  PF-BSE-1A\nMs. Aqsa Zahid  AP-BSE-1B\nMs. Rabia Tabassum
# 09:50-10:40                        NaN                            NaN
#
# Venues/time                                 E6  \
# 08-8:50            CAG-BCY-1B\nMs. Asma Masood
# 08:55-09:45        CAG-BCY-1B\nMs. Asma Masood
# 09:50-10:40  DIS. ST.-BCS-3A\nMr. Shoaib Raza
#
# Venues/time                                R12  \
# 08-8:50      AI-BCS-7A(BCS & BAI)\nMir Murtaza
# 08:55-09:45    DS-BCS-3E\nDr. Jawwad A. Shamsi
# 09:50-10:40  AI-BCS-7A(BCS & BAI)\nMir Murtaza
#
# Venues/time                                R109  \
# 08-8:50            PF-BCY-3A\n Ms. Atiya Jokhio
# 08:55-09:45             CN-BCS-7A(A-J)\nAbuzar
# 09:50-10:40  DIS. ST.-BCS-3E\nMr. Fahad Hussain
#
# Venues/time                        LLC(R7)  ...  \
# 08-8:50      DS-BCS-3B\nDr. Fahad Sherwani  ...
# 08:55-09:45     COAL-BCS-3A\nMr. Aamir Ali  ...
# 09:50-10:40  COAL-BCS-3B\nMr. Asim Mahmood  ...
#
# Venues/time                            Lab-4  \
# 08-8:50      DS LAB-BCS-3G\nMs. Mafaza Mohi
# 08:55-09:45                              NaN
# 09:50-10:40                              NaN
#
# Venues/time                                      Lab-5  \
# 08-8:50      OOP LAB-BCS-3G(G,H,J,K,L)\nMs. Ayesha Ali
# 08:55-09:45                                        NaN
# 09:50-10:40                                        NaN
#
# Venues/time                            Lab-11  \
# 08-8:50      DS LAB-BCS-3H\nMr. Zuhair Waheed
# 08:55-09:45                               NaN
# 09:50-10:40                               NaN
#
# Venues/time                            Lab-12  \
# 08-8:50      DS LAB-BCS-3J\nMr. M. Ali Fatimi
# 08:55-09:45                               NaN
# 09:50-10:40                               NaN
#
# Venues/time                          EE Lab-6  \
# 08-8:50      DS LAB-BCS-3K\nMr. Mustafa Mirza
# 08:55-09:45                               NaN
# 09:50-10:40                               NaN
#
# Venues/time                               EE Lab-7 EE Lab-8  \
# 08-8:50      ICT LAB-BS(RA)-1C\nMr. Arsalan Sattar      NaN
# 08:55-09:45                                    NaN      NaN
# 09:50-10:40                                    NaN      NaN
#
# Venues/time                      EE Lab-10 EE MPI Lab Electronics Lab
# 08-8:50      DB LAB-BCS-5D\nMr. Amin Sadiq        NaN             NaN
# 08:55-09:45                            NaN        NaN             NaN
# 09:50-10:40                            NaN        NaN             NaN
#
# [3 rows x 41 columns]

# %%
df = df.drop(columns= "CLASSROOMS")   # unneccessary column
df.head(2)
# Out:
# Venues/time                           E1                               E2  \
# 08-8:50      PF-BCS-1J\nMr. Musawar Ali       CAG-BCS-1A\nMr. Nadeem Khan
# 08:55-09:45        CAG-BCS-1J\nMs. Urooj  PF-BCS-1A\nDr. Farooque Hassan
#
# Venues/time                           E3                         E4  \
# 08-8:50      PF-BCS-1F\nMr. M. Shahzad    PF-BSE-1A\nMs. Aqsa Zahid
# 08:55-09:45  PF-BCS-1F\nMr. M. Shahzad    PF-BSE-1A\nMs. Aqsa Zahid
#
# Venues/time                             E5                           E6  \
# 08-8:50      AP-BSE-1B\nMs. Rabia Tabassum  CAG-BCY-1B\nMs. Asma Masood
# 08:55-09:45  AP-BSE-1B\nMs. Rabia Tabassum  CAG-BCY-1B\nMs. Asma Masood
#
# Venues/time                                R12                          R109  \
# 08-8:50      AI-BCS-7A(BCS & BAI)\nMir Murtaza  PF-BCY-3A\n Ms. Atiya Jokhio
# 08:55-09:45    DS-BCS-3E\nDr. Jawwad A. Shamsi       CN-BCS-7A(A-J)\nAbuzar
#
# Venues/time                        LLC(R7)                     A-1 EE  ...  \
# 08-8:50      DS-BCS-3B\nDr. Fahad Sherwani  PF-BCY-1A\nMr. Shahbaz A.  ...
# 08:55-09:45     COAL-BCS-3A\nMr. Aamir Ali  PF-BCY-1A\nMr. Shahbaz A.  ...
#
# Venues/time                            Lab-4  \
# 08-8:50      DS LAB-BCS-3G\nMs. Mafaza Mohi
# 08:55-09:45                              NaN
#
# Venues/time                                      Lab-5  \
# 08-8:50      OOP LAB-BCS-3G(G,H,J,K,L)\nMs. Ayesha Ali
# 08:55-09:45                                        NaN
#
# Venues/time                            Lab-11  \
# 08-8:50      DS LAB-BCS-3H\nMr. Zuhair Waheed
# 08:55-09:45                               NaN
#
# Venues/time                            Lab-12  \
# 08-8:50      DS LAB-BCS-3J\nMr. M. Ali Fatimi
# 08:55-09:45                               NaN
#
# Venues/time                          EE Lab-6  \
# 08-8:50      DS LAB-BCS-3K\nMr. Mustafa Mirza
# 08:55-09:45                               NaN
#
# Venues/time                               EE Lab-7 EE Lab-8  \
# 08-8:50      ICT LAB-BS(RA)-1C\nMr. Arsalan Sattar      NaN
# 08:55-09:45                                    NaN      NaN
#
# Venues/time                      EE Lab-10 EE MPI Lab Electronics Lab
# 08-8:50      DB LAB-BCS-5D\nMr. Amin Sadiq        NaN             NaN
# 08:55-09:45                            NaN        NaN             NaN
#
# [2 rows x 40 columns]

# %% [markdown]
# #### Replacing "\n" with commas for all columns (optional)

# %%
for col in df.columns:
    df[col] = df[col].apply(lambda x: str(x).replace("\n"," , "))
df.head(2)
# Out:
# Venues/time                            E1                                E2  \
# 08-8:50      PF-BCS-1J , Mr. Musawar Ali       CAG-BCS-1A , Mr. Nadeem Khan
# 08:55-09:45        CAG-BCS-1J , Ms. Urooj  PF-BCS-1A , Dr. Farooque Hassan
#
# Venues/time                            E3                          E4  \
# 08-8:50      PF-BCS-1F , Mr. M. Shahzad    PF-BSE-1A , Ms. Aqsa Zahid
# 08:55-09:45  PF-BCS-1F , Mr. M. Shahzad    PF-BSE-1A , Ms. Aqsa Zahid
#
# Venues/time                              E5                            E6  \
# 08-8:50      AP-BSE-1B , Ms. Rabia Tabassum  CAG-BCY-1B , Ms. Asma Masood
# 08:55-09:45  AP-BSE-1B , Ms. Rabia Tabassum  CAG-BCY-1B , Ms. Asma Masood
#
# Venues/time                                 R12  \
# 08-8:50      AI-BCS-7A(BCS & BAI) , Mir Murtaza
# 08:55-09:45    DS-BCS-3E , Dr. Jawwad A. Shamsi
#
# Venues/time                           R109                         LLC(R7)  \
# 08-8:50      PF-BCY-3A ,  Ms. Atiya Jokhio  DS-BCS-3B , Dr. Fahad Sherwani
# 08:55-09:45       CN-BCS-7A(A-J) , Abuzar      COAL-BCS-3A , Mr. Aamir Ali
#
# Venues/time                      A-1 EE  ...  \
# 08-8:50      PF-BCY-1A , Mr. Shahbaz A.  ...
# 08:55-09:45  PF-BCY-1A , Mr. Shahbaz A.  ...
#
# Venues/time                             Lab-4  \
# 08-8:50      DS LAB-BCS-3G , Ms. Mafaza Mohi
# 08:55-09:45                               nan
#
# Venues/time                                       Lab-5  \
# 08-8:50      OOP LAB-BCS-3G(G,H,J,K,L) , Ms. Ayesha Ali
# 08:55-09:45                                         nan
#
# Venues/time                             Lab-11  \
# 08-8:50      DS LAB-BCS-3H , Mr. Zuhair Waheed
# 08:55-09:45                                nan
#
# Venues/time                             Lab-12  \
# 08-8:50      DS LAB-BCS-3J , Mr. M. Ali Fatimi
# 08:55-09:45                                nan
#
# Venues/time                           EE Lab-6  \
# 08-8:50      DS LAB-BCS-3K , Mr. Mustafa Mirza
# 08:55-09:45                                nan
#
# Venues/time                                EE Lab-7 EE Lab-8  \
# 08-8:50      ICT LAB-BS(RA)-1C , Mr. Arsalan Sattar      nan
# 08:55-09:45                                     nan      nan
#
# Venues/time                       EE Lab-10 EE MPI Lab Electronics Lab
# 08-8:50      DB LAB-BCS-5D , Mr. Amin Sadiq        nan             nan
# 08:55-09:45                             nan        nan             nan
#
# [2 rows x 40 columns]

# %% [markdown]
# #### Finding My Section and carefully Excluding combine-section Courses

# %%
def func(series):
     return (series.apply(lambda x: my_section in str(x) and exclude_combine_section_course not in str(x)))

    
mask  = df.apply(lambda x:  func(x), axis=1)
classes = df[mask]

# %% [markdown]
# #### Removing unnecessary Time-slots and Classrooms

# %%
classes = classes.dropna(how='all', axis=0)
classes = classes.dropna(how='all', axis=1)
classes
# Out:
# Venues/time                             R12                         LLC(R7)  \
# 08-8:50                                 NaN                             NaN
# 08:55-09:45                             NaN                             NaN
# 09:50-10:40                             NaN                             NaN
# 11:40-12:30                             NaN  ALGO-BSE-5A , Dr. Waheed Ahmed
# 12:35-01:25  SCD-BSE-5A , Mr. Abdul Rahman                              NaN
# 03:20-04:10                             NaN                             NaN
#
# Venues/time                         A-7 EE                        B-12 EE
# 08-8:50                                NaN   DB-BSE-5A , Ms. Anam Qureshi
# 08:55-09:45                            NaN       SQE-BSE-5A , Ms. Romasha
# 09:50-10:40                            NaN  TBW-BSE-5A , Ms. Sabeen Amjad
# 11:40-12:30                            NaN                            NaN
# 12:35-01:25                            NaN                            NaN
# 03:20-04:10  TBW-BSE-5A , Ms. Sabeen Amjad                            NaN

# %% [markdown]
# Here we are all set to run excat same code for all Days of the week

# %% [markdown]
# ### PUTTING IT ALL TOGETHER FOR EACH DAYS

# %%
from IPython.display import display, HTML

# %%
Days = ["MONDAY", "TUESDAY", "WEDNESDAY", "THURSDAY","FRIDAY"]

# %%
def func(series):
    return (series.apply(lambda x: my_section in str(x) and exclude_combine_section_course not in str(x)))


for day in Days[:]:
    df = pd.read_excel("FAST School of Computing - Fall 2022 - V0.xlsx", sheet_name=day, header=2)
    
    # Transposing the data-frame so that index becomes the time of the classes/
    df = df.T
    
    #Removing the Serial number(after transposing) as column names   #Don't run it more than once          
    df.columns = df.iloc[0]
    df = df.drop(df.index[0])
    df = df.drop(columns= "CLASSROOMS")   # unneccessary column

    #replacing "\n" with ","
    for col in df.columns:
        df[col] = df[col].apply(lambda x: str(x).replace("\n"," , "))

    mask  = df.apply(lambda x:  func(x), axis=1)
    
    classes = df[mask]
    classes = classes.dropna(how='all', axis=0)
    classes = classes.dropna(how='all', axis=1)
    classes = classes.replace(np.nan, "-")
    
    print("\n\t\t\t\t\t",day,"\n")
    # print(tabulate(classes, headers='keys', tablefmt='psql'))
    display(HTML(classes.to_html()))
# Out:
# 					 MONDAY
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Venues/time</th>
#       <th>R12</th>
#       <th>LLC(R7)</th>
#       <th>A-7 EE</th>
#       <th>B-12 EE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>08-8:50</th>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>DB-BSE-5A , Ms. Anam Qureshi</td>
#     </tr>
#     <tr>
#       <th>08:55-09:45</th>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>SQE-BSE-5A , Ms. Romasha</td>
#     </tr>
#     <tr>
#       <th>09:50-10:40</th>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>TBW-BSE-5A , Ms. Sabeen Amjad</td>
#     </tr>
#     <tr>
#       <th>11:40-12:30</th>
#       <td>-</td>
#       <td>ALGO-BSE-5A , Dr. Waheed Ahmed</td>
#       <td>-</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>12:35-01:25</th>
#       <td>SCD-BSE-5A , Mr. Abdul Rahman</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>03:20-04:10</th>
#       <td>-</td>
#       <td>-</td>
#       <td>TBW-BSE-5A , Ms. Sabeen Amjad</td>
#       <td>-</td>
#     </tr>
#   </tbody>
# </table>
# 					 TUESDAY
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Venues/time</th>
#       <th>A-7 EE</th>
#       <th>B-12 EE</th>
#       <th>C-20 EE</th>
#       <th>Lab-5</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>08-8:50</th>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>DB LAB-BSE-5A  , Ms. Syeda Ulya Seerat</td>
#     </tr>
#     <tr>
#       <th>11:40-12:30</th>
#       <td>-</td>
#       <td>DB-BSE-5A , Ms. Anam Qureshi</td>
#       <td>-</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>12:35-01:25</th>
#       <td>SCD-BSE-5A ,  Mr. Abdul Rahman</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>02:25-03:15</th>
#       <td>-</td>
#       <td>-</td>
#       <td>SQE-BSE-5A , Ms. Romasha</td>
#       <td>-</td>
#     </tr>
#   </tbody>
# </table>
# 					 WEDNESDAY
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Venues/time</th>
#       <th>B-9 EE</th>
#       <th>B-11 EE</th>
#       <th>B-12 EE</th>
#       <th>Lab-11</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>08-8:50</th>
#       <td>SQE-BSE-5A , Ms. Romasha</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>08:55-09:45</th>
#       <td>SCD-BSE-5A , Mr. Abdul Rahman</td>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>09:50-10:40</th>
#       <td>-</td>
#       <td>DB-BSE-5A , Ms. Anam Qureshi</td>
#       <td>-</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>10:45-11:35</th>
#       <td>-</td>
#       <td>-</td>
#       <td>ALGO-BSE-5A , Dr. Waheed Ahmed</td>
#       <td>-</td>
#     </tr>
#     <tr>
#       <th>12:35-01:25</th>
#       <td>-</td>
#       <td>-</td>
#       <td>-</td>
#       <td>SCD LAB-BSE-5A , Ms. Nida Munawar</td>
#     </tr>
#   </tbody>
# </table>
# 					 THURSDAY
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Venues/time</th>
#       <th>E1</th>
#       <th>A-7 EE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>08:55-09:45</th>
#       <td>-</td>
#       <td>TBW-BSE-5A , Ms. Sabeen Amjad</td>
#     </tr>
#     <tr>
#       <th>10:45-11:35</th>
#       <td>ALGO-BSE-5A , Dr. Waheed Ahmed</td>
#       <td>-</td>
#     </tr>
#   </tbody>
# </table>
# 					 FRIDAY
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Venues/time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# # Hurry!!! We did it...
